# %% [markdown]
# # Start coding and Enjoy the journey

# %% [markdown]
# ## Install the repo

# %%
# !git clone --recursive https://github.com/miguelfbml/Visual-Place-Recognition-Project.git
# Out:
# Cloning into 'Visual-Place-Recognition-Project'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 112 (delta 6), reused 112 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (112/112), 1.34 MiB | 4.70 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# Submodule 'image-matching-models' (https://github.com/alexstoken/image-matching-models.git) registered for path 'image-matching-models'
# Cloning into '/content/Visual-Place-Recognition-Project/image-matching-models/Visual-Place-Recognition-Project/image-matching-models'...
# remote: Enumerating objects: 1546, done.
# remote: Counting objects: 100% (587/587), done.
# remote: Compressing objects: 100% (269/269), done.
# remote: Total 1546 (delta 367), reused 362 (delta 318), pack-reused 959 (from 2)
# Receiving objects: 100% (1546/1546), 88.51 MiB | 34.14 MiB/s, done.
# Resolving deltas: 100% (1039/1039), done.
# ...

# %% [markdown]
# ## Install dependencies

# %%
# %cd Visual-Place-Recognition-Project/image-matching-models
# !pip install -e .[all]
# Out:
# /content/Visual-Place-Recognition-Project/image-matching-models/Visual-Place-Recognition-Project/image-matching-models
# Obtaining file:///content/Visual-Place-Recognition-Project/image-matching-models/Visual-Place-Recognition-Project/image-matching-models
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached kornia-0.8.2-py2.py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached transforms3d-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached kornia_moons-0.2.9-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# ...
#   Using cached vispy-0.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# ...
#   Using cached pyglet-1.5.28-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached trimesh-4.10.1-py3-none-any.whl.metadata (13 kB)
# ...

# %%
# !pip install faiss-cpu
# Out:
# ...
#   Using cached faiss_cpu-1.13.1-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 58.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Download Datasets

# %%
# !python ../download_datasets.py
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=15QB3VNKj93027UAQWv7pzFQO1JDCdZj2
# From (redirected): https://drive.google.com/uc?id=15QB3VNKj93027UAQWv7pzFQO1JDCdZj2&confirm=t&uuid=bb552613-0664-4496-ad39-712dee110eb2
# To: /content/Visual-Place-Recognition-Project/image-matching-models/Visual-Place-Recognition-Project/image-matching-models/data/tokyo_xs.zip
# 100% 141M/141M [00:01<00:00, 114MB/s]
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1tQqEyt3go3vMh4fj_LZrRcahoTbzzH-y
# From (redirected): https://drive.google.com/uc?id=1tQqEyt3go3vMh4fj_LZrRcahoTbzzH-y&confirm=t&uuid=0cfc77c5-1052-4a20-a4a3-aaa44ed1ccaa
# To: /content/Visual-Place-Recognition-Project/image-matching-models/Visual-Place-Recognition-Project/image-matching-models/data/sf_xs.zip
# 100% 1.03G/1.03G [00:12<00:00, 81.4MB/s]
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1q7usSe9_5xV5zTfN-1In4DlmF5ReyU_A
# ...

# %% [markdown]
# ## Run your First VPR Evalutation

# %% [markdown]
# ## cosplace

# %% [markdown]
# ### tokyo

# %% [markdown]
# l2

# %%
# !python ../VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir cosplace_tokyo \
--method=cosplace --backbone=ResNet18 --descriptors_dimension=512 \
--image_size 512 512 \
--database_folder ../image-matching-models/data/tokyo_xs/test/database \
--queries_folder ../image-matching-models/data/tokyo_xs/test/queries \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty
# Out:
# 2025-12-09 22:15:59 ../VPR-methods-evaluation/main.py --num_workers 8 --batch_size 32 --log_dir cosplace_tokyo_l2 --method=cosplace --backbone=ResNet18 --descriptors_dimension=512 --image_size 512 512 --database_folder ../image-matching-models/data/tokyo_xs/test/database --queries_folder ../image-matching-models/data/tokyo_xs/test/queries --num_preds_to_save 20 --recall_values 1 5 10 20 --save_for_uncertainty
# 2025-12-09 22:15:59 Arguments: Namespace(positive_dist_threshold=25, method='cosplace', backbone='ResNet18', descriptors_dimension=512, database_folder='../image-matching-models/data/tokyo_xs/test/database', queries_folder='../image-matching-models/data/tokyo_xs/test/queries', num_workers=8, batch_size=32, log_dir='cosplace_tokyo_l2', device='cuda', recall_values=[1, 5, 10, 20], no_labels=False, num_preds_to_save=20, save_only_wrong_preds=False, image_size=[512, 512], save_descriptors=False, save_for_uncertainty=True, faiss_metric='l2', use_labels=True)
# ...

# %% [markdown]
# ### sf

# %% [markdown]
# l2

# %%
# !python ../VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir cosplace_sf \
--method=cosplace --backbone=ResNet18 --descriptors_dimension=512 \
--image_size 512 512 \
--database_folder ../image-matching-models/data/sf_xs/test/database \
--queries_folder ../image-matching-models/data/sf_xs/test/queries \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty
# Out:
# 2025-12-09 22:26:04 ../VPR-methods-evaluation/main.py --num_workers 8 --batch_size 32 --log_dir cosplace_sf_l2 --method=cosplace --backbone=ResNet18 --descriptors_dimension=512 --image_size 512 512 --database_folder ../image-matching-models/data/sf_xs/test/database --queries_folder ../image-matching-models/data/sf_xs/test/queries --num_preds_to_save 20 --recall_values 1 5 10 20 --save_for_uncertainty
# 2025-12-09 22:26:04 Arguments: Namespace(positive_dist_threshold=25, method='cosplace', backbone='ResNet18', descriptors_dimension=512, database_folder='../image-matching-models/data/sf_xs/test/database', queries_folder='../image-matching-models/data/sf_xs/test/queries', num_workers=8, batch_size=32, log_dir='cosplace_sf_l2', device='cuda', recall_values=[1, 5, 10, 20], no_labels=False, num_preds_to_save=20, save_only_wrong_preds=False, image_size=[512, 512], save_descriptors=False, save_for_uncertainty=True, faiss_metric='l2', use_labels=True)
# ...

# %% [markdown]
# ### svox_night

# %% [markdown]
# l2

# %%
# !python ../VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir cosplace_svoxnight \
--method=cosplace --backbone=ResNet18 --descriptors_dimension=512 \
--image_size 512 512 \
--database_folder ../image-matching-models/data/svox/images/test/gallery \
--queries_folder ../image-matching-models/data/svox/images/test/queries_night \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %% [markdown]
# ### svox_day

# %% [markdown]
# l2

# %%
# !python ../VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir cosplace_svoxday \
--method=cosplace --backbone=ResNet18 --descriptors_dimension=512 \
--image_size 512 512 \
--database_folder ../image-matching-models/data/svox/images/test/gallery \
--queries_folder ../image-matching-models/data/svox/images/test/queries_sun \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %% [markdown]
# ## NetVLAD

# %% [markdown]
# ### tokyo

# %% [markdown]
# l2

# %%
# !python ../VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir netvlad_tokyo \
--method=netvlad --descriptors_dimension=4096 \
--database_folder ../image-matching-models/data/tokyo_xs/test/database \
--queries_folder ../image-matching-models/data/tokyo_xs/test/queries \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %% [markdown]
# ### sf

# %% [markdown]
# l2

# %%
# !python ../VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir netvlad_sf \
--method=netvlad --descriptors_dimension=4096 \
--database_folder ../image-matching-models/data/sf_xs/test/database \
--queries_folder ../image-matching-models/data/sf_xs/test/queries \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %% [markdown]
# ### svox_night

# %% [markdown]
# l2

# %%
# !python ../VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir netvlad_svoxnight \
--method=netvlad --descriptors_dimension=4096 \
--database_folder ../image-matching-models/data/svox/images/test/gallery \
--queries_folder ../image-matching-models/data/svox/images/test/queries_night \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %% [markdown]
# ### svox_day

# %% [markdown]
# l2

# %%
# !python ../VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir netvlad_svoxday \
--method=netvlad --descriptors_dimension=4096 \
--database_folder ../image-matching-models/data/svox/images/test/gallery \
--queries_folder ../image-matching-models/data/svox/images/test/queries_sun \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %% [markdown]
# ## Run Image Matching on Retrieval Results

# %%
'''
# !python match_queries_preds.py \
--preds-dir '<path-to-predictions-folder>' \
--matcher 'superpoint-lg' \
--device 'cuda' \
--num-preds 20
'''

# %% [markdown]
# ## cosplace

# %% [markdown]
# SuperPoint+LightGlue

# %% [markdown]
# ### tokyo

# %%
# !python match_queries_preds.py \
--preds-dir 'cosplace_tokyo' \
--matcher 'superpoint-lg' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### sf

# %%
# !python match_queries_preds.py \
--preds-dir 'cosplace_sf' \
--matcher 'superpoint-lg' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### svox_night

# %%
# !python match_queries_preds.py \
--preds-dir 'cosplace_svoxnight' \
--matcher 'superpoint-lg' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### svox_day

# %%
# !python match_queries_preds.py \
--preds-dir 'cosplace_svoxday' \
--matcher 'superpoint-lg' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# LoFTR

# %% [markdown]
# ### tokyo

# %%
# !python match_queries_preds.py \
--preds-dir 'cosplace_tokyo' \
--matcher 'loftr' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### sf

# %%
# !python match_queries_preds.py \
--preds-dir 'cosplace_sf' \
--matcher 'loftr' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### svox_night

# %%
# !python match_queries_preds.py \
--preds-dir 'cosplace_svoxnight' \
--matcher 'loftr' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### svox_day

# %%
# !python match_queries_preds.py \
--preds-dir 'cosplace_svoxday' \
--matcher 'loftr' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# SuperGlue

# %% [markdown]
# ### tokyo

# %%
# !python match_queries_preds.py \
--preds-dir 'cosplace_tokyo' \
--matcher 'superglue' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### sf

# %%
# !python match_queries_preds.py \
--preds-dir 'cosplace_sf' \
--matcher 'superglue' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### svox_night

# %%
# !python match_queries_preds.py \
--preds-dir 'cosplace_svoxnight' \
--matcher 'superglue' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### svox_day

# %%
# !python match_queries_preds.py \
--preds-dir 'cosplace_svoxday' \
--matcher 'superglue' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### NetVLAD

# %% [markdown]
# SuperPoint+LightGlue

# %% [markdown]
# ### tokyo

# %%
# !python match_queries_preds.py \
--preds-dir 'netvlad_tokyo' \
--matcher 'superpoint-lg' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### sf

# %%
# !python match_queries_preds.py \
--preds-dir 'netvlad_sf' \
--matcher 'superpoint-lg' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### svox_night

# %%
# !python match_queries_preds.py \
--preds-dir 'netvlad_svoxnight' \
--matcher 'superpoint-lg' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### svox_day

# %%
# !python match_queries_preds.py \
--preds-dir 'netvlad_svoxday' \
--matcher 'superpoint-lg' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# LoFTR

# %% [markdown]
# ### tokyo

# %%
# !python match_queries_preds.py \
--preds-dir 'netvlad_tokyo' \
--matcher 'loftr' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### sf

# %%
# !python match_queries_preds.py \
--preds-dir 'netvlad_sf' \
--matcher 'loftr' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### svox_night

# %%
# !python match_queries_preds.py \
--preds-dir 'netvlad_svoxnight' \
--matcher 'loftr' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### svox_day

# %%
# !python match_queries_preds.py \
--preds-dir 'netvlad_svoxday' \
--matcher 'loftr' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# SuperGlue

# %% [markdown]
# ### tokyo

# %%
# !python match_queries_preds.py \
--preds-dir 'netvlad_tokyo' \
--matcher 'superglue' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### sf

# %%
# !python match_queries_preds.py \
--preds-dir 'netvlad_sf' \
--matcher 'superglue' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### svox_night

# %%
# !python match_queries_preds.py \
--preds-dir 'netvlad_svoxnight' \
--matcher 'superglue' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ### svox_day

# %%
# !python match_queries_preds.py \
--preds-dir 'netvlad_svoxday' \
--matcher 'superglue' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ## Check Re-ranking Performance

# %%
'''
# !python reranking.py \
--preds-dir '<path-to-predictions-folder>' \
--inliers-dir '<path-to-inliers-folder>' \
--num-preds 20 \
--recall-values 1 5 10 20
'''

# %% [markdown]
# ### CosPlace

# %% [markdown]
# SuperPoint+LightGlue

# %% [markdown]
# ### tokyo

# %%
# !python reranking.py \
--preds-dir 'cosplace_tokyo' \
--inliers-dir 'cosplace_tokyo/inliers_superpoint-lg.torch' \
--num-preds 20 \
--recall-values 1 5 10 20

# %% [markdown]
# ### sf

# %%
# !python reranking.py \
--preds-dir 'cosplace_sf' \
--inliers-dir 'cosplace_sf/inliers_superpoint-lg.torch' \
--num-preds 20 \
--recall-values 1 5 10 20

# %% [markdown]
# ### svox_night

# %%
# !python reranking.py \
--preds-dir 'cosplace_svoxnight' \
--inliers-dir 'cosplace_svoxnight/inliers_superpoint-lg.torch' \
--num-preds 20 \
--recall-values 1 5 10 20

# %% [markdown]
# ### svox_day

# %%
# !python reranking.py \
--preds-dir 'cosplace_svoxday' \
--inliers-dir 'cosplace_svoxday/inliers_superpoint-lg.torch' \
--num-preds 20 \
--recall-values 1 5 10 20

# %% [markdown]
# LoFTR

# %% [markdown]
# ### tokyo

# %%
# !python reranking.py \
--preds-dir 'cosplace_tokyo' \
--inliers-dir 'cosplace_tokyo/inliers_loftr.torch' \
--num-preds 20 \
--recall-values 1 5 10 20

# %% [markdown]
# ### sf

# %%
# !python reranking.py \
--preds-dir 'cosplace_sf' \
--inliers-dir 'cosplace_sf/inliers_loftr.torch' \
--num-preds 20 \
--recall-values 1 5 10 20

# %% [markdown]
# ### svox_night

# %%
# !python reranking.py \
--preds-dir 'cosplace_svoxnight' \
--inliers-dir 'cosplace_svoxnight/inliers_loftr.torch' \
--num-preds 20 \
--recall-values 1 5 10 20

# %% [markdown]
# ### svox_day

# %%
# !python reranking.py \
--preds-dir 'cosplace_svoxday' \
--inliers-dir 'cosplace_svoxday/inliers_loftr.torch' \
--num-preds 20 \
--recall-values 1 5 10 20

# %% [markdown]
# SuperGlue

# %% [markdown]
# ### tokyo

# %%
# !python reranking.py \
--preds-dir 'cosplace_tokyo' \
--inliers-dir 'cosplace_tokyo/inliers_superglue.torch' \
--num-preds 20 \
--recall-values 1 5 10 20

# %% [markdown]
# ### sf

# %%
# !python reranking.py \
--preds-dir 'cosplace_sf' \
--inliers-dir 'cosplace_sf/inliers_superglue.torch' \
--num-preds 20 \
--recall-values 1 5 10 20

# %% [markdown]
# ### svox_night

# %%
# !python reranking.py \
--preds-dir 'cosplace_svoxnight' \
--inliers-dir 'cosplace_svoxnight/inliers_superglue.torch' \
--num-preds 20 \
--recall-values 1 5 10 20

# %% [markdown]
# ### svox_day

# %%
# !python reranking.py \
--preds-dir 'cosplace_svoxday' \
--inliers-dir 'cosplace_svoxday/inliers_superglue.torch' \
--num-preds 20 \
--recall-values 1 5 10 20

# %% [markdown]
# ## Perform Uncertainty Evalutation

# %% [markdown]
# ## Analyze Inliers: Correlation between R@1 Correctness and Inlier Count
#
# This section analyzes whether the number of inliers can distinguish between correct and wrong R@1 predictions.

# %% [markdown]
# ### CosPlace

# %% [markdown]
# #### SuperPoint+LightGlue

# %%
# !python analyze_inliers.py \
--preds-dir 'cosplace_tokyo' \
--matcher 'superpoint-lg' \
--output-dir 'analysis_results/cosplace_superpoint-lg_tokyo'

# %%
# !python analyze_inliers.py \
--preds-dir 'cosplace_sf' \
--matcher 'superpoint-lg' \
--output-dir 'analysis_results/cosplace_superpoint-lg_sf'

# %%
# !python analyze_inliers.py \
--preds-dir 'cosplace_svoxnight' \
--matcher 'superpoint-lg' \
--output-dir 'analysis_results/cosplace_superpoint-lg_svoxnight'

# %%
# !python analyze_inliers.py \
--preds-dir 'cosplace_svoxday' \
--matcher 'superpoint-lg' \
--output-dir 'analysis_results/cosplace_superpoint-lg_svoxday'

# %% [markdown]
# #### LoFTR

# %%
# !python analyze_inliers.py \
--preds-dir 'cosplace_tokyo' \
--matcher 'loftr' \
--output-dir 'analysis_results/cosplace_loftr_tokyo'

# %%
# !python analyze_inliers.py \
--preds-dir 'cosplace_sf' \
--matcher 'loftr' \
--output-dir 'analysis_results/cosplace_loftr_sf'

# %%
# !python analyze_inliers.py \
--preds-dir 'cosplace_svoxnight' \
--matcher 'loftr' \
--output-dir 'analysis_results/cosplace_loftr_svoxnight'

# %%
# !python analyze_inliers.py \
--preds-dir 'cosplace_svoxday' \
--matcher 'loftr' \
--output-dir 'analysis_results/cosplace_loftr_svoxday'

# %% [markdown]
# #### SuperGlue

# %%
# !python analyze_inliers.py \
--preds-dir 'cosplace_tokyo' \
--matcher 'superglue' \
--output-dir 'analysis_results/cosplace_superglue_tokyo'

# %%
# !python analyze_inliers.py \
--preds-dir 'cosplace_sf' \
--matcher 'superglue' \
--output-dir 'analysis_results/cosplace_superglue_sf'

# %%
# !python analyze_inliers.py \
--preds-dir 'cosplace_svoxnight' \
--matcher 'superglue' \
--output-dir 'analysis_results/cosplace_superglue_svoxnight'

# %%
# !python analyze_inliers.py \
--preds-dir 'cosplace_svoxday' \
--matcher 'superglue' \
--output-dir 'analysis_results/cosplace_superglue_svoxday'

# %% [markdown]
# ### NetVLAD

# %% [markdown]
# #### SuperPoint+LightGlue

# %%
# !python analyze_inliers.py \
--preds-dir 'netvlad_tokyo' \
--matcher 'superpoint-lg' \
--output-dir 'analysis_results/netvlad_superpoint-lg_tokyo'

# %%
# !python analyze_inliers.py \
--preds-dir 'netvlad_sf' \
--matcher 'superpoint-lg' \
--output-dir 'analysis_results/netvlad_superpoint-lg_sf'

# %%
# !python analyze_inliers.py \
--preds-dir 'netvlad_svoxnight' \
--matcher 'superpoint-lg' \
--output-dir 'analysis_results/netvlad_superpoint-lg_svoxnight'

# %%
# !python analyze_inliers.py \
--preds-dir 'netvlad_svoxday' \
--matcher 'superpoint-lg' \
--output-dir 'analysis_results/netvlad_superpoint-lg_svoxday'

# %% [markdown]
# #### LoFTR

# %%
# !python analyze_inliers.py \
--preds-dir 'netvlad_tokyo' \
--matcher 'loftr' \
--output-dir 'analysis_results/netvlad_loftr_tokyo'

# %%
# !python analyze_inliers.py \
--preds-dir 'netvlad_sf' \
--matcher 'loftr' \
--output-dir 'analysis_results/netvlad_loftr_sf'

# %%
# !python analyze_inliers.py \
--preds-dir 'netvlad_svoxnight' \
--matcher 'loftr' \
--output-dir 'analysis_results/netvlad_loftr_svoxnight'

# %%
# !python analyze_inliers.py \
--preds-dir 'netvlad_svoxday' \
--matcher 'loftr' \
--output-dir 'analysis_results/netvlad_loftr_svoxday'

# %% [markdown]
# #### SuperGlue

# %%
# !python analyze_inliers.py \
--preds-dir 'netvlad_tokyo' \
--matcher 'superglue' \
--output-dir 'analysis_results/netvlad_superglue_tokyo'

# %%
# !python analyze_inliers.py \
--preds-dir 'netvlad_sf' \
--matcher 'superglue' \
--output-dir 'analysis_results/netvlad_superglue_sf'

# %%
# !python analyze_inliers.py \
--preds-dir 'netvlad_svoxnight' \
--matcher 'superglue' \
--output-dir 'analysis_results/netvlad_superglue_svoxnight'

# %%
# !python analyze_inliers.py \
--preds-dir 'netvlad_svoxday' \
--matcher 'superglue' \
--output-dir 'analysis_results/netvlad_superglue_svoxday'

# %% [markdown]
# ## Perform Uncertainty Evalutation

# %%
# !python -m vpr_uncertainty.eval \
--preds-dir '<path-to-predictions-folder>' \
--inliers-dir '<path-to-inliers-folder>' \
--z-data-path '<path-to-z-data-file>'
